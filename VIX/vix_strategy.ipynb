# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

os.chdir('C:/Users/new00/Documents/Frank/Intern/cta')
print(os.getcwd())
# Out:
# C:\Users\new00\Documents\Frank\Intern\cta

# %%
from future_data_loader import *

if __name__ == '__main__':
    loader = FutureDataLoader(ric = 'VX', start_date = '2010-01-01', end_date = '2025-03-01')
    display(loader.main_contract)
    display(loader.intraday)
    plt.plot(loader.main_contract['close'])
    plt.tight_layout()
    plt.show()

    plt.plot(loader.intraday['close'])
    plt.tight_layout()
    plt.show()
# Out:
# ...
# Loading Intraday Data...: 100%|██████████| 183/183 [00:15<00:00, 11.70it/s]
#        datetime   open   high    low    close  volume  position contract  \
# 0    2010-01-04  22.50  22.50  22.05  22.1000    6683     34174   VX_F10
# 1    2010-01-05  22.15  22.30  21.50  21.5500    7634     34654   VX_F10
# 2    2010-01-06  21.65  21.65  20.80  20.8000    3729     34654   VX_F10
# 3    2010-01-07  21.00  21.25  20.40  20.4500    3374     36337   VX_F10
# 4    2010-01-08  20.65  20.70  19.85  19.9000    4387     28887   VX_F10
# ...         ...    ...    ...    ...      ...     ...       ...      ...
# 3814 2025-02-24  18.10  18.85  17.65  18.4302  152793    197932   VX_H25
# 3815 2025-02-25  18.35  19.40  18.05  18.4836  182928    202055   VX_H25
# 3816 2025-02-26  18.35  18.75  17.60  18.1337  134427    185070   VX_H25
# 3817 2025-02-27  17.80  19.35  17.65  19.3063  164843    178805   VX_H25
# 3818 2025-02-28  19.25  20.00  18.70  18.8291  184717    159440   VX_H25
#
# ...
